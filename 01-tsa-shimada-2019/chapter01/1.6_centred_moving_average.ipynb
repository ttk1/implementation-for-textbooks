# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_ice = pd.read_csv('../../data/chapter01/icecream.csv')

# %%
df_ice
# Out:
#      year  month  expenditure_yen
# 0    2003      1              331
# 1    2003      2              268
# 2    2003      3              365
# 3    2003      4              492
# 4    2003      5              632
# 5    2003      6              730
# 6    2003      7              821
# 7    2003      8             1057
# 8    2003      9              724
# 9    2003     10              430
# 10   2003     11              363
# 11   2003     12              415
# 12   2004      1              351
# 13   2004      2              322
# 14   2004      3              367
# 15   2004      4              508
# 16   2004      5              667
# 17   2004      6              772
# 18   2004      7             1148
# 19   2004      8             1080
# 20   2004      9              653
# 21   2004     10              434
# 22   2004     11              358
# 23   2004     12              388
# 24   2005      1              323
# 25   2005      2              283
# 26   2005      3              357
# 27   2005      4              543
# 28   2005      5              667
# 29   2005      6              812
# ..    ...    ...              ...
# 90   2010      7             1211
# 91   2010      8             1451
# 92   2010      9              864
# 93   2010     10              504
# 94   2010     11              351
# 95   2010     12              423
# 96   2011      1              346
# 97   2011      2              289
# 98   2011      3              329
# 99   2011      4              462
# 100  2011      5              672
# 101  2011      6              791
# 102  2011      7             1265
# 103  2011      8             1241
# 104  2011      9              767
# 105  2011     10              516
# 106  2011     11              393
# 107  2011     12              423
# 108  2012      1              339
# 109  2012      2              274
# 110  2012      3              385
# 111  2012      4              524
# 112  2012      5              671
# 113  2012      6              798
# 114  2012      7             1165
# 115  2012      8             1332
# 116  2012      9              849
# 117  2012     10              515
# 118  2012     11              326
# 119  2012     12              414
#
# [120 rows x 3 columns]

# %%
df_ice.expenditure_yen.plot()

# %%
# 移動平均
df_ma = df_ice.expenditure_yen.rolling(window=12).mean().shift(-6)
# 中心化移動平均
df_cma = df_ma.rolling(window=2).mean()

# 中心化移動平均系列
df_cma.plot(style='--', label='CMA')
# 原系列
df_ice.expenditure_yen.plot(label='observation')

# %%
df_cma
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6      553.166667
# 7      556.250000
# 8      558.583333
# 9      559.333333
# 10     561.458333
# 11     564.666667
# 12     580.041667
# 13     594.625000
# 14     592.625000
# 15     589.833333
# 16     589.791667
# 17     588.458333
# 18     586.166667
# 19     583.375000
# 20     581.333333
# 21     582.375000
# 22     583.833333
# 23     585.500000
# 24     582.541667
# 25     582.041667
# 26     589.750000
# 27     594.125000
# 28     593.125000
# 29     590.125000
#           ...
# 90     658.583333
# 91     657.250000
# 92     654.333333
# 93     652.000000
# 94     648.583333
# 95     643.166667
# 96     643.333333
# 97     636.833333
# 98     624.041667
# 99     620.500000
# 100    622.750000
# 101    624.500000
# 102    624.208333
# 103    623.291667
# 104    625.000000
# 105    629.916667
# 106    632.458333
# 107    632.708333
# 108    628.833333
# 109    628.458333
# 110    635.666667
# 111    639.041667
# 112    636.208333
# 113    633.041667
# 114           NaN
# 115           NaN
# 116           NaN
# 117           NaN
# 118           NaN
# 119           NaN
# Name: expenditure_yen, Length: 120, dtype: float64
